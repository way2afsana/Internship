# %% [markdown]
# ### 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
#
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\future\anaconda3\lib\site-packages (4.8.3)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\future\anaconda3\lib\site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\future\anaconda3\lib\site-packages (from selenium) (0.10.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\future\anaconda3\lib\site-packages (from selenium) (1.26.14)
# Requirement already satisfied: trio~=0.17 in c:\users\future\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\future\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: idna in c:\users\future\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\future\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\future\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.1)
# Requirement already satisfied: sniffio in c:\users\future\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\future\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\future\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\future\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: wsproto>=0.14 in c:\users\future\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\future\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\future\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\future\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
import time

# %%
# connecting to webdriver
driver=webdriver.Chrome(r'C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe') #connecting to webdriver
time.sleep(2)

# Opening Wikipedia webpage
url='https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)
time.sleep(2)
# Out:
# C:\Users\Future\AppData\Local\Temp\ipykernel_33412\3977769751.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe') #connecting to webdriver

# %%
from selenium.webdriver.common.by import By

# %%
# Empty list for scraping data
Rank =[]
Name =[]
Artist =[]
Upload_date=[]
Views=[]

# %%
# Extracting Rank Via X path
try:
    rank=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[1]')
    for i in rank:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('NA')
except StaleElementReferenceException:
    Rank.append('NA')
    
# Extracting Name Via X path
try:
    name=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[2]')
    for i in name:
        Name.append(i.text)
except NoSuchElementExceptionhElementException:
    Name.append('NA')
except StaleElementReferenceException:
    Name.append('NA')
    
# Extracting Artist Name Via Xpath
try:
    artist=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]")
    for i in artist:
        Artist.append(i.text)
except NoSuchElementExceptionhElementException:
    Artist.append('NA')
except StaleElementReferenceException:
    Artist.append('NA')

# Extracting Upload date Via Xpath
try:
    upload_date=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]")
    for i in upload_date:
        Upload_date.append(i.text)
except NoSuchElementExceptionhElementException:
    Upload_date.append('NA')
except StaleElementReferenceException:
    Upload_date.append('NA') 

# Extracting Views via Xpath
try:
    views=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]")
    for i in views:
        Views.append(i.text)
except NoSuchElementExceptionhElementException:
    Views.append('NA')
except StaleElementReferenceException:
    Views.append('NA')

# %%
# Dataframe for scrap data
Wiki_YT=pd.DataFrame({'Rank':Rank,'Video Name':Name,'Uploader':Artist,'Views (in Billons)':Views,'Upload Date':Upload_date})
print('\033[1m'+'Most Viewed Video on YouTube from Wikipedia :'+'\033[0m')
Wiki_YT
# Out:
# Most Viewed Video on YouTube from Wikipedia :
#    Rank                                       Video Name  \
# 0    1.                            "Baby Shark Dance"[4]
# 1    2.                                   "Despacito"[7]
# 2    3.                       "Johny Johny Yes Papa"[14]
# 3    4.                                  "Bath Song"[15]
# 4    5.                               "Shape of You"[16]
# 5    6.                              "See You Again"[18]
# 6    7.                "Phonics Song with Two Words"[23]
# 7    8.                          "Wheels on the Bus"[24]
# 8    9.                                "Uptown Funk"[25]
# 9   10.  "Learning Colors – Colorful Eggs on a Farm"[26]
# 10  11.                              "Gangnam Style"[27]
# 11  12.   "Masha and the Bear – Recipe for Disaster"[32]
# 12  13.                             "Dame Tu Cosita"[33]
# 13  14.                                     "Axel F"[34]
# 14  15.                                      "Sugar"[35]
# 15  16.                                       "Roar"[36]
# 16  17.                             "Counting Stars"[37]
# 17  18.                                      "Sorry"[38]
# 18  19.                        "Baa Baa Black Sheep"[39]
# 19  20.                          "Thinking Out Loud"[40]
# 20  21.           "Waka Waka (This Time for Africa)"[41]
# 21  22.                                 "Dark Horse"[42]
# 22  23.                                      "Faded"[43]
# 23  24.                                    "Perfect"[44]
# 24  25.                             "Lakdi Ki Kathi"[45]
# 25  26.                                 "Let Her Go"[46]
# 26  27.                             "Girls Like You"[47]
# 27  28.          "Humpty the train on a fruits ride"[48]
# 28  29.                                    "Lean On"[49]
# 29  30.                                   "Bailando"[50]
#
#                                          Uploader Views (in Billons)  \
# 0     Pinkfong Baby Shark - Kids' Songs & Stories              12.73
# 1                                      Luis Fonsi               8.14
# 2                                     LooLoo Kids               6.69
# 3                      Cocomelon – Nursery Rhymes               6.15
# 4                                      Ed Sheeran               5.97
# 5                                     Wiz Khalifa               5.86
# 6                                       ChuChu TV               5.26
# 7                      Cocomelon – Nursery Rhymes               5.14
# 8                                     Mark Ronson               4.89
# 9                                     Miroshka TV               4.87
# 10                                            Psy               4.77
# 11                                     Get Movies               4.55
# 12                                      El Chombo               4.32
# 13                                     Crazy Frog               3.87
# 14                                       Maroon 5               3.86
# 15                                     Katy Perry               3.78
# 16                                    OneRepublic               3.77
# 17                                  Justin Bieber               3.65
# 18                     Cocomelon – Nursery Rhymes               3.61
# 19                                     Ed Sheeran               3.58
# 20                                        Shakira               3.56
# 21                                     Katy Perry               3.50
# 22                                    Alan Walker               3.44
# 23                                     Ed Sheeran               3.42
# 24                                   Jingle Toons               3.42
# 25                                      Passenger               3.42
# 26                                       Maroon 5               3.40
# 27  Kiddiestv Hindi – Nursery Rhymes & Kids Songs               3.38
# 28                                    Major Lazer               3.37
# 29                               Enrique Iglesias               3.37
#
#           Upload Date
# 0       June 17, 2016
# 1    January 12, 2017
# 2     October 8, 2016
# 3         May 2, 2018
# 4    January 30, 2017
# 5       April 6, 2015
# 6       March 6, 2014
# 7        May 24, 2018
# 8   November 19, 2014
# 9   February 27, 2018
# 10      July 15, 2012
# 11   January 31, 2012
# 12      April 5, 2018
# 13      June 16, 2009
# 14   January 14, 2015
# 15  September 5, 2013
# 16       May 31, 2013
# 17   October 22, 2015
# 18      June 25, 2018
# 19    October 7, 2014
# 20       June 4, 2010
# 21  February 20, 2014
# 22   December 3, 2015
# 23   November 9, 2017
# 24      June 14, 2018
# 25      July 25, 2012
# 26       May 31, 2018
# 27   January 26, 2018
# 28     March 22, 2015
# 29     April 11, 2014

# %% [markdown]
# ####

# %% [markdown]
# ### 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
#
# You need to find following details:A) Match title (I.e. 1st ODI),B) Series,C) Place,D) Date,E) Time
#
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.webdriver.common.by import By
import time

# %%
# connecting to webdriver
driver=webdriver.Chrome(r'C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe')
time.sleep(2)

# Opening Wikipedia webpage
url='https://www.bcci.tv/'
driver.get(url)
time.sleep(2)
# Out:
# C:\Users\Future\AppData\Local\Temp\ipykernel_40196\3717562579.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe')

# %%
# Opening fixtures webpage through browser
fixture=driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a')
try:
    fixture.click()
except ElementNotInteractableException:
    driver.get(fixtures.get_attribute('href'))

# %%
# Creating empty list
Title = []
Series = []
Place = []
Date = []
Time = []

# %%
from tqdm import tqdm
for i in tqdm(URL):
    driver.get(i)
    
    # Scraping Match title
    try:
        title=driver.find_element(By.XPATH,'//h5[@class="match-tournament-name ng-binding"]')
        Title.append(title.text)
    except NoSuchElementException:
        Title.append('NA')
        
    # Scraping Series Via Xpath
    try:
        series=driver.find_element(By.XPATH,'//div[@class="small-seprator"]')
        Series.append(series.text)
    except NoSuchElementException:
        Series.append('NA')
        
    # Scraping venue Via Xpath
    try:
        place=driver.find_element(By.XPATH,'//div[@class="match-place ng-scope"]')
        Place.append(place.text)
    except NoSuchElementException:
        Place.append('NA')
        
    # Scraping date Via Xpath
    try:
        date=driver.find_element(By.XPATH,'//div[@class="match-dates ng-binding"]')
        Date.append(date.text)
    except NoSuchElementException:
        Date.append('NA')
        
    # Scraping Time Via Xpath
    try:
        time=driver.find_element(By.XPATH,'//div[@class="match-time no-margin ng-binding"]')
        Time.append(time.text)
    except NoSuchElementException:
        Time.append('NA')
# Out:
# 0it [00:00, ?it/s]

# %%
# Dataframe for scrap data
Cricket=pd.DataFrame({'Match Title':Title,'Tournament':Series,'Venue':Place,'Date':Date,'Time':Time})
print('\033[1m'+'Team India’s Upcoming International fixtures :'+'\033[0m')
Cricket
# Out:
# Team India’s Upcoming International fixtures :
# Empty DataFrame
# Columns: [Match Title, Tournament, Venue, Date, Time]
# Index: []

# %% [markdown]
# ## 3. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
#
# You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP at current price (19-20)
#
# D) GSDP at current price (18-19)
#
# E) Share(18-19)
#
# F) GDP($ billion)
#
# Note: - From statisticstimes home page you have to reach to economy page through code

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementNotInteractableException
import time

# %%
# connecting to webdriver
driver=webdriver.Chrome(r'C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe')
time.sleep(1)

# Opening Wikipedia webpage
url='https://www.statisticstimes.com/'
driver.get(url)
time.sleep(1)
# Out:
# C:\Users\Future\AppData\Local\Temp\ipykernel_17604\1251977572.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe')

# %%
# Creating Empty lists
Rank =[]
State =[]
GDSP_19_20=[]
GDSP_18_19 =[]
Share =[]
GDP =[]

# %%
# Clicking on India under ecomony section
India=driver.find_element(By.XPATH,'//div[@class="dropdown"][2]/div/a[3]')
try:
    India.click()
except ElementNotInteractableException:
    driver.get(India.get_attribute('href'))
    
time.sleep(2)

# Clicking Indian State GDP
state = driver.find_element(By.XPATH,'//ul[@style="list-style-type:none;margin-left:20px;"]/li[1]/a')
try:
    state.click()
except ElementNotInteractableException:
    driver.get(state.get_attribute('href'))
time.sleep(2)

# %%
# Extracting Rank via Xpath
try:
    rank=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[1]')
    for i in rank:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('NA')
    
# Extracting state name via Xpath
try:
    state=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[2]')
    for i in state:
        State.append(i.text)
except NoSuchElementException:
    State.append('NA')
    
# Extracting GDSP 19-20 via Xpath
try:
    gdsp_19_20=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[3]')
    for i in gdsp_19_20:
        GDSP_19_20.append(i.text)
except NoSuchElementException:
    GDSP_19_20.append('NA')
    
# Extracting GDSP 18-19 via Xpath
try:
    gdsp_18_19=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[4]')
    for i in gdsp_18_19:
        GDSP_18_19.append(i.text)
except NoSuchElementException:
    GDSP_18_19.append('NA')
    
# Extracting share in billons via Xpath
try:
    share=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[5]')
    for i in share:
        Share.append(i.text)
except NoSuchElementException:
    Share.append('NA')

# Extracting GDP via Xpath
try:
    gdp=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[6]')
    for i in gdp:
        GDP.append(i.text)
except NoSuchElementException:
    GDP.append('NA')

# %%
# Dataframe for scrap data
Statewise_GDP=pd.DataFrame({'Rank':Rank,'State':State,'GDSP 19-20':GDSP_19_20,'GDSP 18-19':GDSP_18_19,
                            'Share':Share,'GDP (in Billions)':GDP})
print('\033[1m'+'State-wise GDP of India :'+'\033[0m')
Statewise_GDP
# Out:
# State-wise GDP of India :
#    Rank                      State GDSP 19-20 GDSP 18-19   Share  \
# 0     1                Maharashtra          -  2,632,792  13.94%
# 1     2                 Tamil Nadu  1,845,853  1,630,208   8.63%
# 2     3              Uttar Pradesh  1,687,818  1,584,764   8.39%
# 3     4                    Gujarat          -  1,502,899   7.96%
# 4     5                  Karnataka  1,631,977  1,493,127   7.91%
# 5     6                West Bengal  1,253,832  1,089,898   5.77%
# 6     7                  Rajasthan  1,020,989    942,586   4.99%
# 7     8             Andhra Pradesh    972,782    862,957   4.57%
# 8     9                  Telangana    969,604    861,031   4.56%
# 9    10             Madhya Pradesh    906,672    809,592   4.29%
# 10   11                     Kerala          -    781,653   4.14%
# 11   12                      Delhi    856,112    774,870   4.10%
# 12   13                    Haryana    831,610    734,163   3.89%
# 13   14                      Bihar    611,804    530,363   2.81%
# 14   15                     Punjab    574,760    526,376   2.79%
# 15   16                     Odisha    521,275    487,805   2.58%
# 16   17                      Assam          -    315,881   1.67%
# 17   18               Chhattisgarh    329,180    304,063   1.61%
# 18   19                  Jharkhand    328,598    297,204   1.57%
# 19   20                Uttarakhand          -    245,895   1.30%
# 20   21            Jammu & Kashmir          -    155,956   0.83%
# 21   22           Himachal Pradesh    165,472    153,845   0.81%
# 22   23                        Goa     80,449     73,170   0.39%
# 23   24                    Tripura     55,984     49,845   0.26%
# 24   25                 Chandigarh          -     42,114   0.22%
# 25   26                 Puducherry     38,253     34,433   0.18%
# 26   27                  Meghalaya     36,572     33,481   0.18%
# 27   28                     Sikkim     32,496     28,723   0.15%
# 28   29                    Manipur     31,790     27,870   0.15%
# 29   30                   Nagaland          -     27,283   0.14%
# 30   31          Arunachal Pradesh          -     24,603   0.13%
# 31   32                    Mizoram     26,503     22,287   0.12%
# 32   33  Andaman & Nicobar Islands          -          -       -
#
#    GDP (in Billions)
# 0            399.921
# 1            247.629
# 2            240.726
# 3            228.290
# 4            226.806
# 5            165.556
# 6            143.179
# 7            131.083
# 8            130.791
# 9            122.977
# 10           118.733
# 11           117.703
# 12           111.519
# 13            80.562
# 14            79.957
# 15            74.098
# 16            47.982
# 17            46.187
# 18            45.145
# 19            37.351
# 20            23.690
# 21            23.369
# 22            11.115
# 23             7.571
# 24             6.397
# 25             5.230
# 26             5.086
# 27             4.363
# 28             4.233
# 29             4.144
# 30             3.737
# 31             3.385
# 32                 -

# %% [markdown]
# ## 4. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
#
# You have to find the following details:
#
# A) Repository title
#
# B) Repository description
#
# C) Contributors count
#
# D) Language used

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementNotInteractableException
import time

# %%
# connecting to webdriver
driver=webdriver.Chrome(r'C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe')
time.sleep(1)

# Opening Wikipedia webpage
url='https://github.com/'
driver.get(url)
time.sleep(1)
# Out:
# C:\Users\Future\AppData\Local\Temp\ipykernel_17604\3151841900.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe')

# %%
# Clicking on trending option
trending=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/div[3]/ul/li[2]/a')
try:
    trending.click()
except ElementNotInteractableException:
    driver.get(trending.get_attribute('href'))

# %%
# Creating Empty list for Scraping Data
Title=[]
Description=[]
Count =[]
Language =[]

# %%
# Scraping repositories URL
URL= []
link=driver.find_elements(By.XPATH,'//h2[@class="h3 lh-condensed"]/a')
for i in link:
    URL.append(i.get_attribute('href'))

# %%
len(URL)
# Out:
# 25

# %%
# Scraping Repositority Title
try:
    title=driver.find_elements(By.XPATH,'//h2[@class="h3 lh-condensed"]')
    for i in title:
        Title.append(i.text)
except NoSuchElementException:
    Title.append('NA')

# %%
len(Title)
# Out:
# 25

# %%
from tqdm import tqdm
for i in tqdm(URL):
    driver.get(i)
    time.sleep(5)
    # Scraping Description
    try:
        description=driver.find_element(By.XPATH,'/html/body/div[4]/div/main/div[2]/div/div/div[2]/div[2]/div/div[1]/div/p')
        Description.append(description.text)
    except NoSuchElementException:
        Description.append('NA')
    
    # Scraping Contributor count
    try:
        count=driver.find_element(By.XPATH,"//h2[@class='h4 mb-3']/a[contains(text(),'Contributors')]/span")
        Count.append(count.text)
    except NoSuchElementException:
        Count.append('NA')
    
    # Scraping Language
    L =[]
    try:
        lang=driver.find_elements(By.XPATH,"//li[@class='d-inline']//a//span[1]")
        if lang:
            for j in lang:
                L.append(j.text)
        else:
            L.append('NA')
        Language.append(L)
    except NoSuchElementException:
        Language.append('NA')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [04:18<00:00, 10.34s/it]

# %%
Github=pd.DataFrame({'Title':Title,'Description':Description,
                'Contributors_count':Count,'Language_used':Language})
print('\033[1m'+'GitHub Trending Repository :'+'\033[0m')
Github
# Out:
# GitHub Trending Repository :
#                                        Title Description Contributors_count  \
# 0                          xtekky / gpt4free          NA                 23
# 1                            mitsuhiko / rye          NA                 13
# 2                     sindresorhus / awesome          NA                556
# 3                        Josh-XT / Agent-LLM          NA                 11
# 4                    whoiskatrin / chart-gpt          NA                 11
# 5                        Snaacky / dndserver          NA                  8
# 6                        lvwzhen / law-cn-ai          NA                  2
# 7                       GreyDGL / PentestGPT          NA                  3
# 8                   BigBrotherTrade / trader          NA                 NA
# 9                 Dogtiti / AutoGPT-Next-Web          NA                  6
# 10            Developer-Y / cs-video-courses          NA                 87
# 11                      roboflow / notebooks          NA                  9
# 12                      gmpetrov / databerry          NA                  3
# 13                      GitSquared / edex-ui          NA                 60
# 14                            suno-ai / bark          NA                  7
# 15                    xtekky / chatgpt-clone          NA                 12
# 16                              l15y / wenda          NA                 11
# 17                            Eugeny / tabby          NA                107
# 18  isaiahbjork / Auto-GPT-MetaTrader-Plugin          NA                  2
# 19            bullet-train-co / bullet_train          NA                 38
# 20                     modal-labs / quillman          NA                  2
# 21            bethylamine / twitter-archives          NA                  3
# 22                           BloopAI / bloop          NA                 15
# 23              zhayujie / chatgpt-on-wechat          NA                 24
# 24                   farizrahman4u / loopgpt          NA                  8
#
#                                         Language_used
# 0                                [Python, Dockerfile]
# 1                      [Rust, NASL, Python, Makefile]
# 2                                                [NA]
# 3   [Python, JavaScript, Jupyter Notebook, CSS, Do...
# 4                       [TypeScript, CSS, JavaScript]
# 5                                            [Python]
# 6              [TypeScript, CSS, PLpgSQL, JavaScript]
# 7                                      [Python, HTML]
# 8                                            [Python]
# 9    [TypeScript, JavaScript, Shell, CSS, Dockerfile]
# 10                                               [NA]
# 11                                 [Jupyter Notebook]
# 12                      [TypeScript, JavaScript, CSS]
# 13                            [JavaScript, CSS, HTML]
# 14                         [Python, Jupyter Notebook]
# 15        [Python, JavaScript, CSS, HTML, Dockerfile]
# 16                    [CSS, Python, JavaScript, HTML]
# 17  [TypeScript, Pug, SCSS, JavaScript, C++, Batch...
# 18               [Python, Batchfile, Shell, Makefile]
# 19                    [Ruby, JavaScript, Shell, HTML]
# 20                    [JavaScript, Python, CSS, HTML]
# 21                                               [NA]
# 22   [TypeScript, Rust, CSS, Scheme, JavaScript, Nix]
# 23                                    [Python, Shell]
# 24                                           [Python]

# %% [markdown]
# ## 5. Scrape the details of top 100 songs on billboard.com.
# Url = https://www.billboard.com/
#
# You have to find the following details:
#
# A) Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board
#
# Note: - From the home page you have to click on the charts option then hot 100-page link through code

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementNotInteractableException
import time

# %%
# connecting to webdriver
driver=webdriver.Chrome(r'C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe')
time.sleep(1)

# Opening Wikipedia webpage
url='https://www.billboard.com/'
driver.get(url)
time.sleep(1)
# Out:
# C:\Users\Future\AppData\Local\Temp\ipykernel_17604\1843983786.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe')

# %%
# Creating Empty List
Song =[]
Artist =[]
Last_Week_rank=[]
Peak_rank =[]
Weeks =[]

# %%
# Clicking on hot 100 option
hot_100=driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[1]/div/div/div[2]/div/nav/ul/li[1]/a')
try:
    hot_100.click()
except ElementNotInteractableException:
    driver.get(hot_100.get_attribute('href'))
time.sleep(2)

# %%
full_list=driver.find_element(By.XPATH,'/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[3]/a')
full_list.click()

# %%
# Scraping Song Name
try:
    song=driver.find_elements(By.XPATH,'//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li/h3[1]')
    for i in song:
        Song.append(i.text)
except NoSuchElementException:
    Song.append('NA')
    
# Scraping Song Artist Name
try:
    artist=driver.find_elements(By.XPATH,'//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"]')
    for i in artist:
        Artist.append(i.text)
except NoSuchElementException:
    Artist.append('NA')
    
# Scraping Song last week rank
try:
    last_rank=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max lrv-u-flex-grow-1"][1]')
    for i in last_rank:
        Last_Week_rank.append(i.text)
except NoSuchElementException:
    Last_Week_rank.append('NA')

# Scraping Song peak rank
try:
    peak=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-bg-color a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-background-color-grey-lightest lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light lrv-u-flex-grow-1"][2]')
    for i in peak:
        Peak_rank.append(i.text)
except NoSuchElementException:
    Peak_rank.append('NA')

# Scraping Weeks on Chart
try:
    weeks=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max lrv-u-flex-grow-1"][2]')
    for i in weeks:
        Weeks.append(i.text)
except NoSuchElementException:
    Weeks.append('NA')

# %%
Billboard=pd.DataFrame({'Song_Name':Song,
                'Artist_Name':Artist,
                'Last_week_rank':Last_Week_rank,
                'Peak':Peak_rank,
                'Weeks_on_chart':Weeks})
print('\033[1m'+'Billboard Hot 100 Songs :'+'\033[0m')
Billboard
# Out:
# Billboard Hot 100 Songs :
#             Song_Name                              Artist_Name Last_week_rank  \
# 0           Kill Bill                                      SZA              4
# 1          Last Night                            Morgan Wallen              1
# 2             Flowers                              Miley Cyrus              3
# 3      Princess Diana                  Ice Spice & Nicki Minaj              -
# 4     Ella Baila Sola              Eslabon Armado X Peso Pluma             10
# ..                ...                                      ...            ...
# 95        Memory Lane                             Old Dominion             96
# 96         Love Again                            The Kid LAROI             88
# 97         '98 Braves                            Morgan Wallen            100
# 98          Di Que Si  Grupo Marca Registrada X Grupo Frontera              -
# 99  It Matters To Her                          Scotty McCreery              -
#
#    Peak Weeks_on_chart
# 0     1             19
# 1     1             12
# 2     1             14
# 3     4              1
# 4     5              5
# ..  ...            ...
# 95   96              3
# 96   40             12
# 97   27              7
# 98   99              1
# 99  100              1
#
# [100 rows x 5 columns]

# %% [markdown]
# ## 6. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
#
# You have to find the following details:
#
# A) Book name
#
# B) Author name
#
# C) Volumes sold
#
# D) Publisher
#
# E) Genre

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementNotInteractableException
import time

# %%
# connecting to webdriver
driver=webdriver.Chrome(r'C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe')
time.sleep(1)

# Opening Wikipedia webpage
url='https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare'
driver.get(url)
time.sleep(1)
# Out:
# C:\Users\Future\AppData\Local\Temp\ipykernel_17604\1420565522.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe')

# %%
# Creating Empty Lists
Book =[]
Author =[]
Volumes_sold =[]
Publisher =[]
Genre =[]

# %%
# Scraping Book name
try:
    book=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[2]')
    for i in book:
        Book.append(i.text)
except NoSuchElementException:
    Book.append('NA')
    
# Scraping Book author's via Xpath
try:
    author=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[3]')
    for i in author:
        Author.append(i.text)
except NoSuchElementException:
    Author.append('NA')
    
# Scraping Volumes sold via Xpath
try:
    sold=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[4]')
    for i in sold:
        Volumes_sold.append(i.text)
except NoSuchElementException:
    Volumes_sold.append('NA')
    
# Scraping publisher via xPath
try:
    publisher=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[5]')
    for i in publisher:
        Publisher.append(i.text)
except NoSuchElementException:
    Publisher.append('NA')
    
# Scraping Genre via Xpath
try:
    genre=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[6]')
    for i in genre:
        Genre.append(i.text)
except NoSuchElementException:
    Genre.append('NA')

# %%
#creating dataframe
Top_Books=pd.DataFrame({"Book Title":Book,
                "Author Name":Author,
                'Volumes sold':Volumes_sold,
                'Publisher':Publisher,
                'Genre':Genre})
print('\033[1m'+'Best Selling Books of All Time List by The Guardian  :'+'\033[0m')
Top_Books
# Out:
# Best Selling Books of All Time List by The Guardian  :
#                                            Book Title       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes sold        Publisher                        Genre
# 0     5,094,805       Transworld  Crime, Thriller & Adventure
# 1     4,475,152       Bloomsbury           Children's Fiction
# 2     4,200,654       Bloomsbury           Children's Fiction
# 3     4,179,479       Bloomsbury           Children's Fiction
# 4     3,758,936     Random House              Romance & Sagas
# ..          ...              ...                          ...
# 95      807,311     Random House   General & Literary Fiction
# 96      794,201          Penguin        Food & Drink: General
# 97      792,187  Scholastic Ltd.          Young Adult Fiction
# 98      791,507            Orion           Biography: General
# 99      791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %% [markdown]
# ## 7. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
#
# You have to find the following details:
#
# A) Name
#
# B) Year span
#
# C) Genre
#
# D) Run time
#
# E) Ratings
#
# F) Votes

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementNotInteractableException
import time

# %%
# connecting to webdriver
driver=webdriver.Chrome(r'C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe')
time.sleep(1)

# Opening Wikipedia webpage
url='https://www.imdb.com/list/ls095964455/'
driver.get(url)
time.sleep(1)
# Out:
# C:\Users\Future\AppData\Local\Temp\ipykernel_17604\548844808.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe')

# %%
# Creating Empty List
Name =[]
Year_Span=[]
Genre =[]
Run_Time =[]
Ratings =[]
Votes =[]

# %%
# Scraping Name via Xpath
try:
    name=driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/a")
    for i in name:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('NA')

# Scraping Year span via Xpath
try:
    year=driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/span[2]")
    for i in year:
        Year_Span.append(i.text)
except NoSuchElementException:
    Year_Span.append('NA')
    
# Scraping Genre via Xpath
try:
    genre=driver.find_elements(By.XPATH,"//span[@class='genre']")
    for i in genre:
        Genre.append(i.text)
except NoSuchElementException:
    Genre.append('NA')
    
# Scraping RunTime via Xpath
try:
    runtime=driver.find_elements(By.XPATH,"//span[@class='runtime']")
    for i in runtime:
        Run_Time.append(i.text)
except NoSuchElementException:
    Run_Time.append('NA')

# Scraping Ratings via Xpath
try:
    ratings=driver.find_elements(By.XPATH,"//div[@class='ipl-rating-star small']/span[2]")
    for i in ratings:
        Ratings.append(i.text)
except NoSuchElementException:
    Ratings.append('NA')

# Scraping Votes via Xpath
try:
    votes=driver.find_elements(By.XPATH,"//span[@name='nv']")
    for i in votes:
        Votes.append(i.text)
except NoSuchElementException:
    Votes.append('NA')

# %%
#creating dataframe
IMDB_TV=pd.DataFrame({"Name":Name,
                "Year Span":Year_Span,
                "Genre":Genre,
                "Run Time":Run_Time,
                "Ratings":Ratings,
                "Votes":Votes})
print('\033[1m'+'Top 100 most watched tv shows of all time IMDB :'+'\033[0m')
IMDB_TV
# Out:
# Top 100 most watched tv shows of all time IMDB :
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things  (2016–2024)    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds     (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  2,153,798
# 1    51 min     8.7  1,235,778
# 2    44 min     8.1  1,023,128
# 3    60 min     7.5    301,079
# 4    43 min     7.6    260,014
# ..      ...     ...        ...
# 95   42 min     7.4     51,400
# 96   50 min     7.8     63,440
# 97   42 min     8.1    206,853
# 98   45 min       7     42,942
# 99  572 min     8.6    256,501
#
# [100 rows x 6 columns]

# %% [markdown]
# ## 8. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
#
# You have to find the following details:
#
# A) Dataset name
#
# B) Data type
#
# C) Task
#
# D) Attribute type
#
# E) No of instances
#
# F) No of attribute
#
# G) Year
#
# Note: - from the home page you have to go to the Show All Dataset page through code.

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementNotInteractableException
import time

# %%
# connecting to webdriver
driver=webdriver.Chrome(r'C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe')
time.sleep(1)

# Opening Wikipedia webpage
url='https://archive.ics.uci.edu/'
driver.get(url)
time.sleep(1)
# Out:
# C:\Users\Future\AppData\Local\Temp\ipykernel_17604\1337377682.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe')

# %%
# Clicking on all datasets links
dataset=driver.find_element(By.XPATH,"//a[@href='datasets.php']")
dataset.click()
time.sleep(1)

# %%
# Creating empty lists
Dataset =[]
Data_Type =[]
Task =[]
Attribute_Type =[]
No_of_Instances =[]
No_of_Attribute =[]
Year =[]

# %%
# Scraping DataSet Name via Xpath
from tqdm import tqdm
try:
    dataset=driver.find_elements(By.XPATH,"//p[@class='normal']/b/a")
    for i in tqdm(dataset):
        Dataset.append(i.text)
        time.sleep(0.15)
except NoSuchElementException:
    Dataset.append('NA')
    
# Scraping Data Type via Xpath
try:
    Type=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]')
    for i in Type[1:]:
        Data_Type.append(i.text)
except NoSuchElementException:
    Data_Type.append('NA')
    
# Scraping Task via Xpath
try:
    task=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]')
    for i in task[1:]:
        Task.append(i.text)
except NoSuchElementException:
    Task.append('NA')
    
# Scraping Attribute_Type via Xpath
try:
    attribute_Type=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]')
    for i in attribute_Type[1:]:
        Attribute_Type.append(i.text)
except NoSuchElementException:
    Attribute_Type.append('NA')
    
# Scraping No_of_Instances via Xpath
try:
    no_of_Instances=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]')
    for i in no_of_Instances[1:]:
        No_of_Instances.append(i.text)
except NoSuchElementException:
    No_of_Instances.append('NA')

# Scraping No_of_Attribute via Xpath
try:
    no_of_Attribute=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]')
    for i in no_of_Attribute[1:]:
        No_of_Attribute.append(i.text)
except NoSuchElementException:
    No_of_Attribute.append('NA')
    
# Scraping Year via Xpath
try:
    year=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]')
    for i in year[1:]:
        Year.append(i.text)
except NoSuchElementException:
    Year.append('NA')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 622/622 [02:27<00:00,  4.21it/s]

# %%
len(Dataset),len(Data_Type),len(Task),len(Attribute_Type),len(No_of_Instances),len(Year)
# Out:
# (622, 622, 622, 622, 622, 622)

# %%
# Creating Data Frame for UCI Dataset
UCI_Dataset=pd.DataFrame({'DataSet Title':Dataset,
                'Data Type':Data_Type,
                'Task':Task,
                'Attribute Type':Attribute_Type,
                'No of Instances':No_of_Instances,
                'No of Attribute':No_of_Attribute,
                'Year':Year})
print('\033[1m'+' UCI Machine Learning Dataset:'+'\033[0m')
UCI_Dataset
# Out:
#  UCI Machine Learning Dataset:
#                                          DataSet Title  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data Type                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# 4                 Multivariate        Classification
# ..                          ...                   ...
# 617               Multivariate        Classification
# 618               Multivariate        Classification
# 619                                   Classification
# 620  Multivariate, Time-Series        Classification
# 621                 Univariate            Regression
#
#                   Attribute Type No of Instances No of Attribute   Year
# 0    Categorical, Integer, Real            4177               8   1995
# 1          Categorical, Integer           48842              14   1996
# 2    Categorical, Integer, Real             798              38
# 3                   Categorical           37711             294   1998
# 4    Categorical, Integer, Real             452             279   1998
# ..                           ...             ...             ...    ...
# 617               Integer, Real           75840             525   2020
# 618               Integer, Real             400              50   2020
# 619                                        1014               7   2020
# 620                        Real           10129              16   2021
# 621                        Real            4000               2   2021
#
# [622 rows x 7 columns]

# %% [markdown]
# ## 9. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
#
# You have to find the following details:
#
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they hire for
#
# E) Location
#
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementNotInteractableException
import time

# %%
# connecting to webdriver
driver=webdriver.Chrome(r'C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe')
time.sleep(1)

# Opening Wikipedia webpage
url='https://www.naukri.com/hr-recruiters-consultants'
driver.get(url)
time.sleep(1)
# Out:
# C:\Users\Future\AppData\Local\Temp\ipykernel_40196\358737887.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe')

# %%
from selenium.webdriver.common.by import By

# %%
# locating Search bar via Xpath
Search=driver.find_element(By.XPATH,"//input[@class='sugInp']")

# Sending data science as key in search bar
Search.send_keys("Data Science")
time.sleep(1)

#clicking on search button
button=driver.find_element(By.XPATH,"//button[@id='qsbFormBtn']")
button.click()
time.sleep(1)

# %%
# Creating Empty List
Name =[]
Designation =[]
Company =[]
Skill =[]
Location =[]

# %%
# Scraping  Name
try:
    name=driver.find_elements(By.XPATH,'//a[@class="ellipsis"]/span')
    for i in name:
        Name.append(i.text)
except NoSuchElementException:
        Name.append('NA')

    # Scraping Designation
try:
    designation=driver.find_elements(By.XPATH,'//p[@class="highlightable"]/span[1]')
    for i in designation:
        Designation.append(i.text)
except NoSuchElementException:
    Designation.append('NA')
    
# Scraping Company
try:
    company=driver.find_elements(By.XPATH,'//a[@class="ellipsis"][2]')
    for i in company:
        Company.append(i.text)
except NoSuchElementException:
    Company.append('NA')
# Scraping skill for they hire
try:
    skill=driver.find_elements(By.XPATH,'//div[@class="hireSec highlightable"]')
    for i in skill:
        Skill.append(i.text)
except NoSuchElementException:
    Skill.append('NA')
    
# Scraping Song Artist Name
try:
    location=driver.find_elements(By.XPATH,'//p[@class="highlightable"]/span[2]/small')
    if location:
        for i in location:
            Location.append(i.text)
    else:
        Location.append('NA')
except NoSuchElementException:
    Location.append('NA')

# %%
len(Name),len(Designation),len(Company),len(Skill),len(Location)
# Out:
# (50, 50, 50, 50, 49)

# %%
Naukri=pd.DataFrame({})
Naukri['Name']=Name[:49]
Naukri['Designation']=Designation[:49]
Naukri['Company']=Company[:49]
Naukri['Skills I Hire for']=Skill[:49]
Naukri['Location']=Location[:49]
print('\033[1m'+'Naukri.com Data Science recruiters :'+'\033[0m')
Naukri
# Out:
# Naukri.com Data Science recruiters :
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Kalpana Dumpala
# 11                                        Mubarak
# 12                                 Kushal Rastogi
# 13                                 Priyanka Akiri
# 14                                   Kapil Devang
# 15                             Mahesh Babu Channa
# 16                             Vaishnavi Kudalkar
# 17                                Sakshi Chhikara
# 18                                    Ruchi Dhote
# 19                                  Manisha Yadav
# 20                                    Riya Rajesh
# 21                           Rashmi Bhattacharjee
# 22                                  Faizan Kareem
# 23                                 Rithika dadwal
# 24                             Sandhya Khandagale
# 25                                      Shaun Rao
# 26                               Deeparchi Sharma
# 27                                  Azahar Shaikh
# 28                                          Manas
# 29                                          kumar
# 30                                   Sunil Vedula
# 31                                    Rajat Kumar
# 32                                Dhruv Dev Dubey
# 33                                  Avnish Mishra
# 34                                      Jayanth N
# 35                                         Avodha
# 36                                    Priya Khare
# 37                                    Amit Sharma
# 38                                          Kanan
# 39                           Shashikant Chaudhary
# 40                                           Brad
# 41                                   Rutuja Pawar
# 42                            Madhusudhan Sridhar
# 43                                    Ankit Sinha
# 44                                 Gaurav Chouhan
# 45                                   Rashi Kacker
# 46                                        Ashwini
# 47                                   Balaji Kolli
# 48                                 Rajani Nagaraj
#
#                                    Designation  \
# 0                                   HR Manager
# 1                            Company Recruiter
# 2                                   Company HR
# 3                            Company Recruiter
# 4                                  Founder CEO
# 5                  Recruitment Lead Consultant
# 6                            Programme Manager
# 7                             HR Administrator
# 8                                     Director
# 9                               Human Resource
# 10                            Executive Hiring
# 11                                  Company HR
# 12                                  Company HR
# 13                                  HR Manager
# 14                                  HR Manager
# 15                                HR Team Lead
# 16                                HR Executive
# 17                        Assistant Manager HR
# 18         Senior Executive Talent Acquisition
# 19                                HR Executive
# 20                  Manager Talent Acquisition
# 21                                     HR Head
# 22                                  HR MANAGER
# 23                                HR Recruiter
# 24                                HR Recruiter
# 25                     Manager Human Resources
# 26                           Company Recruiter
# 27                           Company Recruiter
# 28                     Lead Talent acquisition
# 29                                  Proprietor
# 30                                         CEO
# 31                                 Founder CEO
# 32                    Company Recruitment Head
# 33  Senior Technical &amp; Corporate Recruiter
# 34                             Project Manager
# 35              Business Development Associate
# 36                              Senior Manager
# 37                                  Consultant
# 38                senior technology instructor
# 39                    HR Recruiter/HR Excutive
# 40               Manager, Technical Recruiting
# 41                         Technical Recruiter
# 42                             Erp Implementer
# 43                              Head Analytics
# 44                     Chief Technical Officer
# 45                          Sr Product Manager
# 46                    Director Global Delivery
# 47                                  Co Founder
# 48                                  HR Manager
#
#                                            Company  \
# 0                             Data Science Network
# 1                    Shore Infotech India Pvt. Ltd
# 2                         MARSIAN Technologies LLP
# 3            Enerlytics Software Solutions Pvt Ltd
# 4                                  LibraryXProject
# 5       Apidel Technologies Division of Transpower
# 6                                             IFMR
# 7                      Techvantage Systems Pvt Ltd
# 8                       Weupskill- Live Wire India
# 9                 CBL Data Science Private Limited
# 10                              Innominds Software
# 11                                        MoneyTap
# 12              QuantMagnum Technologies Pvt. Ltd.
# 13                   Infinitive Software Solutions
# 14                                  BISP Solutions
# 15                               SocialPrachar.com
# 16                             Codeachive learning
# 17                   BIZ INFOTECNO PRIVATE LIMITED
# 18                           Bristlecone India Ltd
# 19                                        Easi Tax
# 20                     Novelworx Digital Solutions
# 21         AXESTRACK SOFTWARE SOLUTIONS PRIVATE...
# 22                   FirstTech Consaltants Pvt.Ltd
# 23                                Affine Analytics
# 24                 Compumatrice Multimedia Pvt Ltd
# 25                              Exela Technologies
# 26                                          ZIGRAM
# 27                 NEAL ANALYTICS SERVICES PVT LTD
# 28      Autumn Leaf Consulting Services Private...
# 29                                         trainin
# 30                            Nanoprecise Sci Corp
# 31                  R.S Consultancy &amp; Services
# 32                               NETAPS FOUNDATION
# 33                   RMS Risk Management Solutions
# 34        Dollarbird Information Services Pvt, Ltd
# 35                              Nikitha Palaparthi
# 36                          Independent Consultant
# 37                                 ASCO consulting
# 38                                         NY INST
# 39  3D India Staffing Research &amp; Consulting...
# 40                                     O.C. Tanner
# 41                                   Demand Matrix
# 42                             MADHUSUDHAN SRIDHAR
# 43                                  Suntech Global
# 44                        Strategic Consulting Lab
# 45                            Impel Labs Pvt. Ltd.
# 46                                    MRP Advisers
# 47                   Saras Solutions India Pvt Ltd
# 48                                     WildJasmine
#
#                                     Skills I Hire for  \
# 0   Classic ASP Developer, Internet Marketing Prof...
# 1   .Net, Java, Data Science, Linux Administration...
# 2   Data Science, Artificial Intelligence, Machine...
# 3   Mean Stack, javascript, angularjs, mongodb, We...
# 4   Hadoop, Spark, Digital Strategy, Data Architec...
# 5   Analytics, Business Intelligence, Business Ana...
# 6                                        Data Science
# 7   Machine Learning, algorithms, Go Getter, Compu...
# 8   Technical Training, Software Development, Pres...
# 9   Software Development, It Sales, Account Manage...
# 10  Qa, Ui/ux, Java Developer, Java Architect, C++...
# 11  Business Intelligence, Data Warehousing, Data ...
# 12  Office Administration, Hr Administration, tele...
# 13  Oracle Dba, Data Science, Data Warehousing, ET...
# 14     Big Data, Hadoop, Data Analytics, Data Science
# 15  Social Media, digital media maketing, seo, smm...
# 16               Data Science, Python, Data Analytics
# 17  React.js, Data Science, Java, Front End, Busin...
# 18  Qlikview, Qlik Sense, Microsoft Azure, Power B...
# 19  Telecalling, Client Interaction, Marketing, Re...
# 20                                       Data Science
# 21  Corporate Sales, Software Development, Softwar...
# 22  Data Analytics, Data Science, Machine Learning...
# 23  Data Science, Machine Learning, Python, R, Dee...
# 24  Big Data, Data Science, Artificial Intelligenc...
# 25  Java, Net, Angularjs, Hr, Infrastructure, Mana...
# 26  Research, Digital Marketing, Analytics, Softwa...
# 27  Data Science, Artificial Intelligence, Machine...
# 28  Software Architecture, Vp Engineering, Product...
# 29  Data Science, Hadoop, Rpas, Devops, Python, Aw...
# 30  Signal Processing, Machine Learning, Neural Ne...
# 31  Web Technologies, Project Management, Software...
# 32  Server Administartion, Verilog, Vhdl, Digital ...
# 33  Data Science, Machine Learning, Deep Learning,...
# 34  Data Analytics, Managed Services, Team Leading...
# 35  Ethical Hacking, Security Operations Center, S...
# 36  Data Science, Artificial Intelligence, analyti...
# 37  Machine Learning, Artificial Intelligence, Dat...
# 38  C, C++, Artificial Intelligence, Python, Php, ...
# 39  Relationship Management, Retail Sales, Private...
# 40                 Data Science, Software Engineering
# 41  Data Science, Big Data Analytics, Digital Mark...
# 42                  Data Science, Recruitment, Salary
# 43  B.Tech, Tableau, Statistics, R, Analytics, Tim...
# 44  Software Development, Business Intelligence, B...
# 45                   Data Science, Node.js, Angularjs
# 46  Data Science, Media Marketing, Resource Planni...
# 47  Data Analysis, Learning, Data Science, Compute...
# 48  Java, Hadoop, R, Machine Learning, Spark, Flum...
#
#                     Location
# 0                      Delhi
# 1   Hyderabad / Secunderabad
# 2                       Pune
# 3                  Ahmedabad
# 4              UK - (london)
# 5          Vadodara / Baroda
# 6                    Chennai
# 7                 Trivandrum
# 8                     Indore
# 9      Bengaluru / Bangalore
# 10  Hyderabad / Secunderabad
# 11     Bengaluru / Bangalore
# 12                    Mumbai
# 13                 Hyderabad
# 14                    Bhopal
# 15  Hyderabad / Secunderabad
# 16                    Mumbai
# 17                Chandigarh
# 18                      Pune
# 19               Navi Mumbai
# 20                    Cochin
# 21                     Delhi
# 22  Hyderabad / Secunderabad
# 23                      Pune
# 24                      Pune
# 25                      Pune
# 26                   Gurgaon
# 27                      Pune
# 28     Bengaluru / Bangalore
# 29     Bengaluru / Bangalore
# 30                     Delhi
# 31     Bengaluru / Bangalore
# 32                     Noida
# 33           Mysoru / Mysore
# 34  Hyderabad / Secunderabad
# 35     Bengaluru / Bangalore
# 36                 New Delhi
# 37                   Chennai
# 38                   Aligarh
# 39            Salt Lake City
# 40                      Pune
# 41     Bengaluru / Bangalore
# 42                    Mumbai
# 43                    Indore
# 44     Bengaluru / Bangalore
# 45                    MYSORE
# 46  Hyderabad / Secunderabad
# 47     Bengaluru / Bangalore
# 48                    Mumbai
