# %% [markdown]
# ## Q1. Python program to scrape data for “Data Analyst” Job position in “Bangalore” location

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe")

# %%
#Opening the given website on automated chrome browser
driver.get("https://www.naukri.com/")

# %%
#Entering designation as required
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
#Entering location as required
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys('Bangalore')

# %%
#For clicking search button
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
#Scraping JOB TITLE from the page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)

# %%
#Scraping JOB LOCATION from the page
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)

# %%
#Scraping Company Name from the page
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
  company=i.text
  company_name.append(company)

# %%
#Scraping JOB EXPERIENCE from the page
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'Job Title':job_title,'Job Location':job_location,'Company Name':company_name,'Experience Required':experience_required})
df
# Out:
#                              Job Title  \
# 0                         Data Analyst
# 1                     Data Analyst III
# 2                     Data Analyst III
# 3  Compliance Rule Writer/Data Analyst
# 4                         Data Analyst
# 5                Data Analyst - EdTech
# 6                         Data Analyst
# 7           Data Engineer/Data Analyst
# 8           Data Analyst - Contractual
# 9           Data Analyst - Contractual
#
#                                         Job Location  \
# 0                                Bangalore/Bengaluru
# 1                                Bangalore/Bengaluru
# 2                                Bangalore/Bengaluru
# 3                                Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# 6                                Bangalore/Bengaluru
# 7  Hybrid - Bangalore/Bengaluru, Kolkata, Hyderab...
# ...

# %% [markdown]
# #

# %% [markdown]
# ## Q2. Python program to scrape data for “Data Scientist” Job position in  “Bangalore” location

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe")

# %%
#Opening the given website on automated chrome browser
driver.get("https://www.naukri.com/")

# %%
#Entering designation as required
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
#Entering location as required
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys('Bangalore')

# %%
#For clicking search button
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
#Scraping JOB TITLE from the page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)

# %%
#Scraping JOB LOCATION from the page
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)

# %%
#Scraping Company Name from the page
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
  company=i.text
  company_name.append(company)

# %%
#Scraping JOB EXPERIENCE from the page
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'Job Title':job_title,'Job Location':job_location,'Company Name':company_name,'Experience Required':experience_required})
df
# Out:
#                                            Job Title  \
# 0  Data Science Professional - IBM SPSS Statistic...
# 1                            Data Science Specialist
# 2                   Analystics & Modeling Specialist
# 3                              Senior data scientist
# 4                                 Data Scientist_NLP
# 5                                     Data Scientist
# 6                    Machine Learning (AI) Architect
# 7       Manager - Innovations Hub - Machine Learning
# 8                                     Data Scientist
# 9                               Staff Data Scientist
#
#                                         Job Location           Company Name  \
# 0  Bangalore/Bengaluru, Noida, Mumbai, Pune, Chennai  Hexaware Technologies
# 1  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...              Accenture
# 2  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...              Accenture
# ...

# %% [markdown]
# #

# %% [markdown]
# ## Q3. Python Program to Scrape Loacation and Salary Filter

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe")

# %%
#Opening the given website on automated chrome browser
driver.get("https://www.naukri.com/")

# %%
#Entering designation as required
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
#Entering location as required
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys('Delhi/NCR')

# %%
#For clicking search button
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
    #Filtering salary
salary=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/p/span[1]')
salary.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
#Scraping JOB TITLE from the page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)

# %%
#Scraping JOB LOCATION from the page
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)

# %%
#Scraping Company Name from the page
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
  company=i.text
  company_name.append(company)

# %%
#Scraping JOB EXPERIENCE from the page
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'Job Title':job_title,'Job Location':job_location,'Company Name':company_name,'Experience Required':experience_required})
df
# Out:
#                                  Job Title  \
# 0                  Data Science Specialist
# 1                           Data Scientist
# 2                Data Scientist- Bangalore
# 3                Machine Learning Engineer
# 4                    Junior Data Scientist
# 5                    Senior Data Scientist
# 6                           Data Scientist
# 7                           Data Scientist
# 8                           Data Scientist
# 9  MACHINE LEARNING / DATA SCIENCE TRAINER
#
#                                         Job Location  \
# 0  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...
# 1  Temp. WFH - Kochi/Cochin, Kolkata, Hyderabad/S...
# 2                                Bangalore/Bengaluru
# 3                                            Chennai
# 4  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 5                                Bangalore/Bengaluru
# 6              Gurgaon/Gurugram, Bangalore/Bengaluru
# 7                                Bangalore/Bengaluru
# ...

# %% [markdown]
# #

# %% [markdown]
# ## Q4. Data of first 100 sunglasses listings on flipkart.com

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe")

# %%
#Opening the given website on automated chrome browser
driver.get("http://www.flipkart.com/")

# %%
#Removing CROSS sign
cross=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/button")
cross.click()

# %%
#Entering product name as required
product=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
product.send_keys('sunglasses')

# %%
#Clicking SEARCH button
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
brand=[]
product_description=[]
price=[]

# %%
#Scraping Brand from the page
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[0:100]:
    BD=i.text
    brand.append(BD)

# %%
#Scraping product description from the page
description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in description_tags[0:100]:
    PD=i.text   
    product_description.append(PD)

# %%
#Scraping Price from the page
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags[0:100]:
    PR=i.text
    price.append(PR)

# %%
print(len(brand),len(product_description),len(price))
# Out:
# 40 40 40

# %%
df=pd.DataFrame({'Brand':brand,'Product Description':product_description,'Price':price}) #Dataframe of first page
df
# Out:
#                 Brand                                Product Description  \
# 0           Elligator                UV Protection Round Sunglasses (54)
# 1        Singco India  UV Protection, Riding Glasses Retro Square, Re...
# 2           Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...
# 3                SRPM             UV Protection Wayfarer Sunglasses (50)
# 4           Elligator             UV Protection Wayfarer Sunglasses (53)
# 5              PIRASO       UV Protection Aviator Sunglasses (Free Size)
# 6           Elligator    UV Protection Aviator, Wayfarer Sunglasses (54)
# 7              Dervin      UV Protection Wayfarer Sunglasses (Free Size)
# 8              PIRASO           UV Protection Clubmaster Sunglasses (54)
# 9            Fastrack   UV Protection Rectangular Sunglasses (Free Size)
# 10          New Specs   UV Protection Rectangular Sunglasses (Free Size)
# 11     ROZZETTA CRAFT  UV Protection, Gradient Rectangular Sunglasses...
# ...

# %%
brand=[]

# %%
start=0
end=3
for page in range(start,end):
    brands=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brands:
        brand.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
print(len(brand))
# Out:
# 120

# %%
brand[0:100] #required 100 brand names
# Out:
# ['Elligator',
#  'Singco India',
#  'Elligator',
#  'SRPM',
#  'Elligator',
#  'PIRASO',
#  'Elligator',
#  'Dervin',
#  'PIRASO',
#  'Fastrack',
#  'New Specs',
#  'ROZZETTA CRAFT',
#  'PIRASO',
#  'SHAAH COLLECTIONS',
#  'Elligator',
#  'ROZZETTA CRAFT',
#  'Fastrack',
#  'Fastrack',
#  'Fastrack',
#  'ROZZETTA CRAFT',
#  'NuVew',
#  'Fastrack',
#  'Elligator',
#  'Resist',
#  'Fastrack',
#  'SRPM',
#  'PIRASO',
#  'Silver Kartz',
#  'NuVew',
#  'PIRASO',
#  'PIRASO',
#  'AISLIN',
#  'Elligator',
#  'PIRASO',
#  'Fastrack',
#  'Dervin',
#  'NuVew',
#  'Fastrack',
#  'SUNBEE',
#  'AISLIN',
#  'SUNBEE',
#  'Elligator',
#  'Elligator',
#  'AISLIN',
#  'Rich Club',
#  'PIRASO',
#  'Fastrack',
#  'Dervin',
#  'Fastrack',
#  'SUNBEE',
#  'GANSTA',
#  'NuVew',
#  'VINCENT CHASE',
#  'Fastrack',
#  'Fastrack',
#  'RESIST EYEWEAR',
#  'Elligator',
#  'SUNBEE',
#  'Ray-Ban',
#  'AISLIN',
#  'NuVew',
#  'Fastrack',
#  'ROYAL SON',
#  'AISLIN',
#  'PIRASO',
#  'SUNBEE',
#  'PIRASO',
# ...

# %%
product_description=[]

# %%
start=0
end=3
for page in range(start,end):
    p_description=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in p_description:
        product_description.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
print(len(product_description))
# Out:
# 118

# %%
product_description[0:100] #required 100 product description
# Out:
# ['UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (53)',
#  'UV Protection Cat-eye, Retro Square, Oval, Round Sungla...',
#  'UV Protection, Gradient Round, Cat-eye Sunglasses (60)',
#  'UV Protection Retro Square Sunglasses (54)',
#  'UV Protection Aviator Sunglasses (54)',
#  'UV Protection Shield Sunglasses (Free Size)',
#  'UV Protection, Gradient Round Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (53)',
#  'UV Protection, Polarized Wayfarer Sunglasses (Free Size...',
#  'Gradient, UV Protection Aviator Sunglasses (57)',
#  'UV Protection, Gradient Rectangular Sunglasses (Free Si...',
#  'Polarized, UV Protection Rectangular Sunglasses (59)',
#  'Gradient, UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'Others Cat-eye, Retro Square, Wayfarer Sunglasses (54)',
#  'UV Protection Cat-eye Sunglasses (Free Size)',
# ...

# %%
price=[]

# %%
start=0
end=3
for page in range(start,end):
    prices=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in prices:
        price.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
print(len(price))
# Out:
# 120

# %%
price[0:100] #required 100 prices
# Out:
# ['₹245',
#  '₹479',
#  '₹149',
#  '₹149',
#  '₹149',
#  '₹268',
#  '₹149',
#  '₹216',
#  '₹224',
#  '₹274',
#  '₹185',
#  '₹839',
#  '₹179',
#  '₹489',
#  '₹264',
#  '₹695',
#  '₹619',
#  '₹489',
#  '₹549',
#  '₹845',
#  '₹129',
#  '₹149',
#  '₹549',
#  '₹1,799',
#  '₹619',
#  '₹169',
#  '₹99',
#  '₹492',
#  '₹539',
#  '₹182',
#  '₹211',
#  '₹2,199',
#  '₹214',
#  '₹173',
#  '₹149',
#  '₹656',
#  '₹589',
#  '₹99',
#  '₹239',
#  '₹377',
#  '₹185',
#  '₹179',
#  '₹129',
#  '₹485',
#  '₹226',
#  '₹212',
#  '₹629',
#  '₹400',
#  '₹590',
#  '₹293',
#  '₹311',
#  '₹435',
#  '₹901',
#  '₹629',
#  '₹659',
#  '₹393',
#  '₹149',
#  '₹185',
#  '₹3,099',
#  '₹267',
#  '₹129',
#  '₹499',
#  '₹599',
#  '₹1,399',
#  '₹272',
#  '₹179',
#  '₹397',
#  '₹234',
#  '₹190',
#  '₹249',
#  '₹280',
#  '₹108',
#  '₹99',
#  '₹99',
#  '₹729',
#  '₹272',
#  '₹189',
#  '₹929',
#  '₹232',
#  '₹265',
#  '₹245',
#  '₹479',
#  '₹149',
#  '₹149',
#  '₹149',
#  '₹268',
#  '₹149',
#  '₹216',
#  '₹224',
#  '₹274',
# ...

# %% [markdown]
# #

# %% [markdown]
# ## Q5. Scrape 100 reviews data from flipkart.com for iphone11 phone

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe")

# %%
#Opening the given website on automated chrome browser
driver.get("http://www.flipkart.com/")

# %%
#Removing CROSS sign
cross=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/button")
cross.click()

# %%
#Entering product name as required
product=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
product.send_keys('iphone11')

# %%
#Clicking SEARCH button
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
product=driver.find_element(By.CLASS_NAME,"_2kHMtA")
product.click()

# %%
rating=[]
review_summary=[]
full_review=[]

# %%
rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rating_tags[0:9]:
    RAT=i.text
    rating.append(RAT)

# %%
review_tags=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in review_tags[0:9]:
    RS=i.text
    review_summary.append(RS)

# %%
reviewfull_tags=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in reviewfull_tags[0:9]:
    FR=i.text
    full_review.append(FR)

# %%
print(len(rating), len(review_summary),len(full_review))
# Out:
# 8 8 8

# %%
df=pd.DataFrame({'Rating':rating,'Review Summary':review_summary,'Full Review':full_review})
df
# Out:
#   Rating        Review Summary  \
# 0      5      Perfect product!
# 1      5             Just wow!
# 2      4  Good quality product
# 3      5      Perfect product!
# 4      5        Simply awesome
# 5      5             Fabulous!
# 6      5             Fabulous!
# 7      5         Great product
#
#                                          Full Review
# 0  After using 3 years mobile review. Excellent &...
# 1                  Product was good, worked perfect.
# 2  impressively Nice......\nOne of the greatest i...
# 3                         Nice products thanks flkat
# 4  Really satisfied with the Product I received.....
# 5  Best in Iphone series in all feature ! Battery...
# 6  Fast performance to previous iPhone x\nGood ca...
# 7           Awesome product ❤️❤️\nThank you Flipkart

# %%
rating=[]

# %%
start=0
end=13
for page in range(start,end):
    ratings=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in ratings[0:100]:
        rating.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
rating[0:100] #100 ratings
# Out:
# ['5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5']

# %%
review_summary=[]

# %%
start=0
end=12
for page in range(start,end):
    rev_s=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in rev_s[0:100]:
        review_summary.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
review_summary[0:100] #100 review summary
# Out:
# ['Perfect product!',
#  'Just wow!',
#  'Good quality product',
#  'Perfect product!',
#  'Simply awesome',
#  'Fabulous!',
#  'Fabulous!',
#  'Great product',
#  'Perfect product!',
#  'Just wow!',
#  'Good quality product',
#  'Perfect product!',
#  'Simply awesome',
#  'Fabulous!',
#  'Fabulous!',
#  'Great product',
#  'Perfect product!',
#  'Just wow!',
#  'Good quality product',
#  'Perfect product!',
#  'Simply awesome',
#  'Fabulous!',
#  'Fabulous!',
#  'Great product',
#  'Perfect product!',
#  'Just wow!',
#  'Good quality product',
#  'Perfect product!',
#  'Simply awesome',
#  'Fabulous!',
#  'Fabulous!',
#  'Great product',
#  'Perfect product!',
#  'Just wow!',
#  'Good quality product',
#  'Perfect product!',
#  'Simply awesome',
#  'Fabulous!',
#  'Fabulous!',
#  'Great product',
#  'Perfect product!',
#  'Just wow!',
#  'Good quality product',
#  'Perfect product!',
#  'Simply awesome',
#  'Fabulous!',
#  'Fabulous!',
#  'Great product',
#  'Perfect product!',
# ...

# %%
full_review=[]

# %%
start=0
end=12
for page in range(start,end):
    full_rev=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in full_rev[0:100]:
        full_review.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
full_review[0:100] #100 full reviews
# Out:
# ["After using 3 years mobile review. Excellent & Awesome Mobile fully I love it mobile don't wait take it perfectly suits everyone very stylish and operating a...\nRead full review",
#  'Product was good, worked perfect.',
#  "impressively Nice......\nOne of the greatest iPhone i ever used ....\nAll was like Never before ...\nit's just Amazing ...\nBattery Life is too good ...2 Days wi...\nRead full review",
#  'Nice products thanks flkat',
#  'Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.',
#  'Best in Iphone series in all feature ! Battery life is too good!',
#  'Fast performance to previous iPhone x\nGood camera quality but the best part of night mode #killing\n\nI am already One-plus7\nHuge difference between in night m...\nRead full review',
#  'Awesome product ❤️❤️\nThank you Flipkart',
# ...

# %% [markdown]
# #

# %% [markdown]
# ## Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe")

# %%
#Opening the given website on automated chrome browser
driver.get("http://www.flipkart.com/")

# %%
#Removing CROSS sign
cross=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/button")
cross.click()

# %%
#Entering product name as required
product=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
product.send_keys('sneakers')

# %%
#Clicking SEARCH button
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
brand=[]
product_description=[]
price=[]

# %%
#Scraping Brand from the page
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[0:100]:
    BD=i.text
    brand.append(BD)

# %%
#Scraping product description from the page
description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in description_tags[0:100]:
    PD=i.text   
    product_description.append(PD)

# %%
#Scraping Price from the page
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags[0:100]:
    PR=i.text
    price.append(PR)

# %%
print(len(brand),len(product_description),len(price))
# Out:
# 40 40 40

# %%
df=pd.DataFrame({'Brand':brand,'Product Description':product_description,'Price':price}) #Dataframe of first page
df
# Out:
#                   Brand                                Product Description  \
# 0              RapidBox                                   Sneakers For Men
# 1           New Balance                               500 Sneakers For Men
# 2                   SFR                                   Sneakers For Men
# 3                 AMICO                                   Sneakers For Men
# 4                  aadi  Synthetic| Lightweight| Premiun| Comfort| Summ...
# 5                Labbin                                   Sneakers For Men
# 6                 BIRDE      Combo Pack of 2 Casual Shoes Sneakers For Men
# 7              RapidBox                                   Sneakers For Men
# 8                Kraasa                                 Sneakers For Women
# 9                 BIRDE      Combo Pack Of 2 Casual Shoes Sneakers For Men
# 10               BRUTON      Combo Pack Of 2 Casual Shoes Sneakers For Men
# ...

# %%
brand=[]

# %%
start=0
end=3
for page in range(start,end):
    brands=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brands:
        brand.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
print(len(brand))
# Out:
# 120

# %%
brand[0:100]   #required 100 brand names
# Out:
# ['RapidBox',
#  'New Balance',
#  'SFR',
#  'AMICO',
#  'aadi',
#  'Labbin',
#  'BIRDE',
#  'RapidBox',
#  'Kraasa',
#  'BIRDE',
#  'BRUTON',
#  'BRUTON',
#  'aadi',
#  'BIRDE',
#  'BIRDE',
#  'aadi',
#  'New Balance',
#  'SOLETHREADS',
#  'BIRDE',
#  'Magnolia',
#  'New Balance',
#  'PUMA',
#  'World Wear Footwear',
#  'aadi',
#  'Magnolia',
#  'asian',
#  'Kraasa',
#  'aadi',
#  'EZDEZARIO',
#  'BIRDE',
#  'SOLETHREADS',
#  'PUMA',
#  'K- FOOTLANCE',
#  'Xtoon',
#  'AMICO',
#  'BRUTON',
#  'New Balance',
#  'bacca bucci',
#  'BIRDE',
#  'SFR',
#  'Kraasa',
#  'New Balance',
#  'WHITE WALKERS',
#  'asian',
#  'BIRDE',
#  'BIRDE',
#  'RapidBox',
#  'New Balance',
#  'BERSACHE',
#  'WHITE WALKERS',
#  'asian',
#  'SOLETHREADS',
#  'kardam&sons',
#  'Labbin',
#  'Shozie',
#  'BIRDE',
#  'PUMA',
#  'asian',
#  'BIRDE',
#  'Walfos',
#  'asian',
#  'PUMA',
#  'BIRDE',
#  'BIRDE',
#  'Kraasa',
#  'BIRDE',
#  'SOLETHREADS',
#  'PUMA',
#  'BIRDE',
#  'RED TAPE',
#  'PUMA',
#  'bacca bucci',
# ...

# %%
product_description=[]

# %%
start=0
end=3
for page in range(start,end):
    p_description=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in p_description:
        product_description.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
print(len(product_description))
# Out:
# 120

# %%
product_description[0:100]  #required 100 product description
# Out:
# ['Sneakers For Men',
#  'Classic Sneakers For Men',
#  'Stylish & Trending Outdoor Walking Comfortable Sneakers...',
#  'WATERPROOF-05cFULLWHITE Sneakers For Men',
#  'Combo Pack of 2 Sports Sneakers For Men',
#  'Combo Pack of 2 Casual Shoe Sneakers For Men',
#  'Combo Pack Of 2 Casual Shoes Sneakers For Men',
#  '2 Combo Sneaker Shoes Sneakers For Men',
#  'Bersache Lightweight Color Changing Casual,Sneaker Shoe...',
#  'Stylish & Trending Outdoor Walking Comfortable Sneakers...',
#  '237 Sneakers For Men',
#  'Sneakers For Men',
#  'kardam&sons luxury fashionable Stylish Light Weight Sne...',
#  'Casual Sneakers Black Outdoor Shoes For Boys And Men Sn...',
#  'Stylish Sneakers Shoes for Women And Girls Sneakers For...',
#  'Stylish Comfortable Lightweight, Breathable Women Shoes...',
#  'FUTURE PLAY FG/AG Sneakers For Men',
#  'Road Sneakers For Women',
#  'Premium Casual Shoes for Women Sneakers For Women',
#  'Sneakers For Men',
#  '373 Sneakers For Men',
# ...

# %%
price=[]

# %%
start=0
end=3
for page in range(start,end):
    prices=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in prices:
        price.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
print(len(price))
# Out:
# 120

# %%
price[0:100]  #required 100 prices
# Out:
# ['₹571',
#  '₹3,583',
#  '₹299',
#  '₹387',
#  '₹399',
#  '₹379',
#  '₹499',
#  '₹571',
#  '₹499',
#  '₹299',
#  '₹799',
#  '₹3,149',
#  '₹349',
#  '₹499',
#  '₹499',
#  '₹349',
#  '₹1,329',
#  '₹5,849',
#  '₹299',
#  '₹399',
#  '₹1,499',
#  '₹1,099',
#  '₹279',
#  '₹449',
#  '₹399',
#  '₹799',
#  '₹3,644',
#  '₹1,624',
#  '₹429',
#  '₹495',
#  '₹2,549',
#  '₹2,399',
#  '₹199',
#  '₹349',
#  '₹452',
#  '₹279',
#  '₹1,624',
#  '₹5,849',
#  '₹379',
#  '₹279',
#  '₹571',
#  '₹599',
#  '₹449',
#  '₹629',
#  '₹499',
#  '₹499',
#  '₹499',
#  '₹599',
#  '₹449',
#  '₹584',
#  '₹5,066',
#  '₹1,374',
#  '₹549',
#  '₹299',
#  '₹303',
#  '₹299',
#  '₹5,399',
#  '₹299',
#  '₹494',
#  '₹649',
#  '₹4,903',
#  '₹498',
#  '₹449',
#  '₹498',
#  '₹299',
#  '₹499',
#  '₹1,429',
#  '₹2,199',
#  '₹429',
#  '₹379',
#  '₹1,499',
#  '₹4,115',
#  '₹1,231',
#  '₹499',
#  '₹499',
#  '₹299',
#  '₹571',
#  '₹3,443',
#  '₹429',
#  '₹429',
#  '₹571',
#  '₹3,583',
#  '₹299',
#  '₹387',
#  '₹399',
#  '₹379',
# ...

# %% [markdown]
# #

# %% [markdown]
# ##  Q7. Scrape first 10 laptops data from amazon.in

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe")

# %%
#Opening the given website on automated chrome browser
driver.get("https://www.amazon.in/")

# %%
#Entering product name as required
product=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
product.send_keys('Laptop')

# %%
#Clicking SEARCH button
search=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span")
search.click()

# %%
#CPU filter
CPU=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[6]/li[12]/span/a/span")
CPU.click()

# %%
#Required Attributes
title=[]
rating=[]
price=[]

# %%
#scraping required titles
title_tags=driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
for i in title_tags[0:10]:
    TT=i.text
    title.append(TT)

# %%
#scraping required price
price_tags=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in price_tags[0:10]:
    Pri=i.text
    price.append(Pri)

# %%
#scraping required ratings
rating_tags=driver.find_elements(By.XPATH,'//span[@class="a-size-base"]')
for i in rating_tags[0:10]:
    Rat=i.text
    rating.append(Rat)

# %%
print(len(rating), len(title),len(price))
# Out:
# 10 10 10

# %%
df=pd.DataFrame({'Rating':rating,'Title':title,'Price':price})   #first 10 laptops data
df
# Out:
#   Rating                                              Title   Price
# 0    5.0  (Renewed) HP Zbook Mini Server Laptop Intel E3...  58,990
# 1         (Renewed) HP Zbook Mini Server Laptop Intel E3...  74,990
# 2         (Renewed) HP Zbook Mini Server Laptop Intel E3...  52,990
# 3         (Renewed) HP Zbook Mini Server Laptop Intel E3...  66,990
# 4         (Renewed) HP Zbook Mini Server Laptop Intel E3...  56,990
# 5         (Renewed) HP Zbook Mini Server Laptop Intel E3...  47,990
# 6         (Renewed) HP Zbook Mini Server Laptop Intel E3...  48,990
# 7         (Renewed) HP Zbook Mini Server Laptop Intel E3...  57,990
# 8         (Renewed) HP Zbook Mini Server Laptop Intel E3...  51,990
# 9         (Renewed) HP Zbook Mini Server Laptop Intel E3...  46,990

# %% [markdown]
# #

# %% [markdown]
# ## Q8. Python program to scrape data for Top 1000 Quotes of All Time

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe")

# %%
#Opening the given website on automated chrome browser
driver.get("https://www.azquotes.com/")

# %%
#Clicking TOP QUOTES button
Top_quotes=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a")
Top_quotes.click()

# %%
#Required Attributes
quote=[]
author=[]
q_types=[]

# %%
#scraping required qoute
quote_tags=driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in quote_tags:
    QT=i.text
    quote.append(QT)

# %%
#scraping required author
author_names=driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in author_names:
    AN=i.text
    author.append(AN)

# %%
#scraping required types of quote
quote_type=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in quote_type:
    QT=i.text
    q_types.append(QT)

# %%
print(len(quote),len(author),len(q_types))
# Out:
# 100 100 100

# %%
df=pd.DataFrame({'QUOTE':quote,'Author':author,'Types of Quote':q_types})  #First 10 data 
df
# Out:
#                                                 QUOTE                Author  \
# 0   The essence of strategy is choosing what not t...        Michael Porter
# 1   One cannot and must not try to erase the past ...            Golda Meir
# 2   Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3   Death is something inevitable. When a man has ...        Nelson Mandela
# 4   You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                ...                   ...
# 95     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 96  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 97  If you think you are too small to make a diffe...            Dalai Lama
# 98  God doesn't require us to succeed, he only req...         Mother Teresa
# 99    Change your thoughts and you change your world.  Norman Vincent Peale
#
#                               Types of Quote
# ...

# %% [markdown]
# #

# %% [markdown]
# ## Q9: Python program to display list of respected former Prime Ministers of India

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe")

# %%
#Opening the given website on automated chrome browser
driver.get('https://www.jagranjosh.com/')

# %%
#Clicking on GK option
gk=driver.find_element(By.XPATH,"/html/body/div/div[1]/div/div[1]/div/div[5]/div/div[1]/header/div[3]/ul/li[9]/a")
gk.click()

# %%
#Clicking list of all prime minister of India
pm_list=driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a")
pm_list.click()

# %%
#Required attributes
name=[]
born_dead=[]
term=[]
remark=[]

# %%
name_tag=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[2]/p')
for i in name_tag:
    NT=i.text
    name.append(NT)

# %%
borde_tag=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[3]/p')
for i in borde_tag:
    bd=i.text
    born_dead.append(bd)

# %%
term_tag=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[4]')
for i in term_tag:
    tt=i.text
    term.append(tt)

# %%
remark_tag=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[5]/p')
for i in remark_tag:
    rt=i.text
    remark.append(rt)

# %%
print(len(name),len(born_dead),len(term),len(remark))
# Out:
# 18 18 18 18

# %%
df=pd.DataFrame({'Name':name,'Born-Dead':born_dead,'Term of Office':term,'Remark':remark})
df
# Out:
#                            Name     Born-Dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
#
#                                        Term of Office  \
# ...

# %% [markdown]
# #

# %% [markdown]
# ## Q10. Python program to display list of 50 Most expensive cars in the world

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\Future\Desktop\Fliprobo Internship\chromedriver.exe")

# %%
#Opening the given website on automated chrome browser
driver.get('https://www.motor1.com/')

# %%
#Clicking on bar option
bar=driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div/div/div[1]/div")
bar.click()

# %%
#clicking features dropdown button
features=driver.find_element(By.XPATH,"/html/body/div[3]/div[1]/div[3]/ul/li[5]/button")
features.click()

# %%
#Clicking on List option
List=driver.find_element(By.XPATH,"/html/body/div[3]/div[1]/div[3]/ul/li[6]/ul/li[1]/a")
List.click()

# %%
#clicking the exact link to scrape data
exact=driver.find_element(By.XPATH,"/html/body/div[2]/div[8]/div[1]/div[1]/div/div/div[8]/div/div[1]/h3/a")
exact.click()

# %%
car_name=[]
price=[]

# %%
#scraping required car
car_tag=driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in car_tag:
    CT=i.text
    car_name.append(CT)

# %%
#scraping required price
price_tag=driver.find_elements(By.TAG_NAME,"strong")
for i in price_tag:
    PT=i.text
    price.append(PT)

# %%
print(len(car_name),len(price))
# Out:
# 51 51

# %%
df=pd.DataFrame({'Car Name':car_name,'Price':price})   #50 most expensive cars in the world
df.head(50)
# Out:
#                            Car Name                 Price
# 0                     De Tomaso P72   Price: $1.3 Million
# 1                 Ferrari LaFerrari   Price: $1.4 Million
# 2                     Pagani Huayra   Price: $1.4 Million
# 3                      McLaren Elva
# 4                       Czinger 21C   Price: $1.7 Million
# 5                     Ferrari Monza   Price: $1.7 Million
# 6                Gordon Murray T.33   Price: $1.7 Million
# 7                 Koenigsegg Gemera   Price: $1.7 Million
# 8                       Zenvo TSR-S   Price: $1.7 Million
# 9                Hennessey Venom F5   Price: $1.7 Million
# 10                  Bentley Bacalar   Price: $1.8 Million
# 11    Hispano Suiza Carmen Boulogne   Price: $1.9 Million
# 12           Bentley Mulliner Batur   Price: $1.9 Million
# 13                     Deus Vayanne   Price: $2.0 Million
# 14                      SSC Tuatara   Price: $2.0 Million
# 15                      Lotus Evija  Price: $2.0 Million*
# ...

# %%
driver.close()

# %% [markdown]
# #
